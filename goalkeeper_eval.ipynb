# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.metrics import root_mean_squared_error as rmse

# %%
df_translate = pd.read_csv("clean/fbref_to_fpl_api_2425.csv")
df_fpl = pd.read_csv("clean/fpl_api_2425.csv", usecols=[
    "code",
    "total_points",
    "clean_sheets",
])
df_fbref = pd.read_csv("clean/fbref_keeper.csv")

# %%
df_fbref = df_fbref.drop(columns=["league", "season"])

for col in df_fbref.columns:
    if (
        col.startswith("passes")
        or col.startswith("crosses")
        or col.startswith("goal_kicks")
        or col.startswith("launched")
        or col.startswith("sweeper")
    ):
        df_fbref = df_fbref.drop(columns=[col])

# %%
df_fbref = df_fbref.merge(df_translate, left_on="player", right_on="fbref_name", how="inner")
df_all = df_fbref.merge(df_fpl, left_on="fpl_code", right_on="code", how="inner")

# %%
df_all.columns
# Out:
# Index(['team', 'player', 'nation', 'pos', 'age', 'born', 'playing_time_mp',
#        'playing_time_starts', 'playing_time_min', 'playing_time_90s',
#        'performance_ga', 'performance_ga90', 'performance_sota',
#        'performance_saves', 'performance_save%', 'performance_w',
#        'performance_d', 'performance_l', 'performance_cs', 'performance_cs%',
#        'penalty_kicks_pkatt', 'penalty_kicks_pka', 'penalty_kicks_pksv',
#        'penalty_kicks_pkm', 'penalty_kicks_save%', 'goals_fk', 'goals_ck',
#        'goals_og', 'expected_psxg', 'expected_psxg/sot', 'expected_psxg+/-',
#        'expected_/90', 'fbref_name', 'fpl_code', 'clean_sheets', 'code',
#        'total_points'],
#       dtype='object')

# %%
X = df_all[["performance_saves", "performance_save%", "expected_/90"]].dropna()
Y = df_all["total_points"].loc[X.index]
results = sm.OLS(Y, X).fit()
print(rmse(Y, results.fittedvalues))
results.summary()
# Out:
# 19.45829176783204
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           total_points   R-squared (uncentered):                   0.938
# Model:                            OLS   Adj. R-squared (uncentered):              0.933
# Method:                 Least Squares   F-statistic:                              200.8
# Date:                Thu, 14 Aug 2025   Prob (F-statistic):                    3.82e-24
# Time:                        15:17:36   Log-Likelihood:                         -188.65
# No. Observations:                  43   AIC:                                      383.3
# Df Residuals:                      40   BIC:                                      388.6
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# performance_saves     1.1335      0.077     14.689      0.000       0.978       1.289
# performance_save%    -0.0065      0.076     -0.086      0.932      -0.160       0.147
# expected_/90          3.5944      7.368      0.488      0.628     -11.298      18.486
# ==============================================================================
# Omnibus:                        2.096   Durbin-Watson:                   1.635
# Prob(Omnibus):                  0.351   Jarque-Bera (JB):                1.145
# Skew:                           0.190   Prob(JB):                        0.564
# Kurtosis:                       3.703   Cond. No.                         217.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
new_input = pd.DataFrame({
    "performance_saves": [116],
    "performance_save%": [74.4],
    "expected_/90": [0.12]
})

print(results.predict(new_input))
# Out:
# 0    131.426464
# dtype: float64

# %%
df_all["expected_points"] = results.fittedvalues
df_all["residual_points"] = df_all["total_points"] - df_all["expected_points"]
df_all["residual_points_per_90"] = df_all["residual_points"] / df_all["playing_time_min"] * 90

# %%
df_all.sort_values(by="residual_points_per_90", ascending=False)[["player", "total_points", "expected_points", "residual_points_per_90"]].reset_index()
# Out:
#     index                   player  total_points  expected_points  \
# 0      18               Danny Ward             2        -3.311781
# 1       9             Jason Steele             9         1.975503
# 2      24                  Ederson           111        60.303975
# 3      22        Caoimhín Kelleher            45        26.617341
# 4       0               David Raya           142        97.100425
# 5      28          Martin Dúbravka            44        32.731650
# 6      21                  Alisson           112        82.739243
# 7      11           Robert Sánchez           126       103.958700
# 8      13          Jordan Pickford           158       132.605022
# 9      27              André Onana           120        99.402000
# 10     12           Dean Henderson           135       114.331105
# 11     41                  José Sá            93        77.400282
# 12     30                Matz Sels           150       134.686343
# 13     40           Daniel Bentley             9         8.487837
# 14     29                Nick Pope           102        97.224601
# 15      8          Bart Verbruggen           103        97.678418
# 16      1        Emiliano Martínez           111       108.433097
# 17      2              Robin Olsen             9         9.078627
# 18      3        Kepa Arrizabalaga           106       107.447317
# 19      6  Hákon Rafn Valdimarsson             2         2.138952
# 20     14               Bernd Leno           115       119.415470
# 21     25            Stefan Ortega            35        36.743995
# 22     37        Guglielmo Vicario            66        75.878368
# 23     26           Altay Bayındır             8         9.768808
# 24     10          Filip Jørgensen            18        21.212737
# 25     19         Jakub Stolarczyk            25        31.105453
# 26     38          Alphonse Areola            69        86.496728
# 27     17         Christian Walton            16        21.294072
# 28      7             Mark Flekken           138       169.503434
# 29      4             Mark Travers            19        25.345183
# 30     31           Aaron Ramsdale            97       135.285896
# 31     39         Łukasz Fabiański            39        56.616680
# 32     16           Arijanet Muric            49        75.160788
# 33     34           Antonín Kinský            17        26.539321
# 34     35           Brandon Austin             1         2.658898
# 35     36           Fraser Forster            19        30.907165
# 36     42            Sam Johnstone            12        24.121959
# 37     20           Mads Hermansen            63       111.970734
# 38     15              Alex Palmer            22        47.561048
# 39     33               Joe Lumley             8        15.100795
# 40     23          Vitezslav Jaros             1         1.378256
# 41     32            Alex McCarthy            12        26.491858
# 42      5                     Neto             7        16.120374
# 43     43                 Tom King             1              NaN
#
#     residual_points_per_90
# 0                 3.541187
# 1                 3.512248
# 2                 1.966656
# 3                 1.838266
# 4                 1.181568
# 5                 1.126835
# 6                 1.050027
# 7                 0.688791
# 8                 0.668289
# 9                 0.605824
# 10                0.543918
# 11                0.538127
# 12                0.402991
# 13                0.256081
# 14                0.170550
# 15                0.147822
# 16                0.072330
# 17               -0.031311
# 18               -0.046688
# 19               -0.086246
# 20               -0.116197
# 21               -0.142690
# 22               -0.411599
# 23               -0.442202
# 24               -0.535456
# 25               -0.610545
# 26               -0.696772
# 27               -0.756296
# 28               -0.865743
# 29               -1.269037
# 30               -1.276197
# 31               -1.366811
# 32               -1.453377
# 33               -1.589887
# 34               -1.658898
# 35               -1.701024
# 36               -1.731708
# 37               -1.847952
# 38               -1.966234
# 39               -2.366932
# 40               -2.836922
# 41               -2.898372
# 42               -4.560187
# 43                     NaN

# %%
df_all[["player", "playing_time_starts", "playing_time_min", "total_points"]]
# Out:
#                      player  playing_time_starts  playing_time_min  \
# 0                David Raya                   38              3420
# 1         Emiliano Martínez                   37              3194
# 2               Robin Olsen                    1               226
# 3         Kepa Arrizabalaga                   31              2790
# 4              Mark Travers                    5               450
# 5                      Neto                    2               180
# 6   Hákon Rafn Valdimarsson                    1               145
# 7              Mark Flekken                   37              3275
# 8           Bart Verbruggen                   36              3240
# 9              Jason Steele                    2               180
# 10          Filip Jørgensen                    6               540
# 11           Robert Sánchez                   32              2880
# 12           Dean Henderson                   38              3420
# 13          Jordan Pickford                   38              3420
# 14               Bernd Leno                   38              3420
# 15              Alex Palmer                   13              1170
# 16           Arijanet Muric                   18              1620
# 17         Christian Walton                    7               630
# 18               Danny Ward                    1               135
# 19         Jakub Stolarczyk                   10               900
# 20           Mads Hermansen                   27              2385
# 21                  Alisson                   28              2508
# 22        Caoimhín Kelleher                   10               900
# 23          Vitezslav Jaros                    0                12
# 24                  Ederson                   26              2320
# 25            Stefan Ortega                   12              1100
# 26           Altay Bayındır                    4               360
# 27              André Onana                   34              3060
# 28          Martin Dúbravka                   10               900
# 29                Nick Pope                   28              2520
# 30                Matz Sels                   38              3420
# 31           Aaron Ramsdale                   30              2700
# 32            Alex McCarthy                    5               450
# 33               Joe Lumley                    3               270
# 34           Antonín Kinský                    6               540
# 35           Brandon Austin                    1                90
# 36           Fraser Forster                    7               630
# 37        Guglielmo Vicario                   24              2160
# 38          Alphonse Areola                   25              2260
# 39         Łukasz Fabiański                   13              1160
# 40           Daniel Bentley                    2               180
# 41                  José Sá                   29              2609
# 42            Sam Johnstone                    7               630
# 43                 Tom King                    0                 1
#
#     total_points
# 0            142
# 1            111
# 2              9
# 3            106
# 4             19
# 5              7
# 6              2
# 7            138
# 8            103
# 9              9
# 10            18
# 11           126
# 12           135
# 13           158
# 14           115
# 15            22
# 16            49
# 17            16
# 18             2
# 19            25
# 20            63
# 21           112
# 22            45
# 23             1
# 24           111
# 25            35
# 26             8
# 27           120
# 28            44
# 29           102
# 30           150
# 31            97
# 32            12
# 33             8
# 34            17
# 35             1
# 36            19
# 37            66
# 38            69
# 39            39
# 40             9
# 41            93
# 42            12
# 43             1
